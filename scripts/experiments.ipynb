# %%
import os
import itertools
import numpy as np

# %%
experiments_path = '/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/OASIS-3_mean_loss'
labels_path = '/cluster/tufts/hugheslab/eharve06/encoded_OASIS-3_CT'
random_states = [1001, 2001, 3001, 4001, 5001, 6001, 7001, 8001, 9001, 10001, 11001, 12001, 13001, 14001, 15001]
ns = [60, 94, 147, 230, 360, 414, 475, 546]
count = 0
for n, random_states in itertools.product(ns, random_states):
    count += 1
    print('    "python ../src/finetune_3D.py --experiments_path=\'{}\' --labels_path=\'{}\' --n={} --random_state={}"'.format(experiments_path, labels_path, n, random_states))
print(count)
# Out:
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/OASIS-3_mean_loss' --labels_path='/cluster/tufts/hugheslab/eharve06/encoded_OASIS-3_CT' --n=60 --random_state=1001"
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/OASIS-3_mean_loss' --labels_path='/cluster/tufts/hugheslab/eharve06/encoded_OASIS-3_CT' --n=60 --random_state=2001"
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/OASIS-3_mean_loss' --labels_path='/cluster/tufts/hugheslab/eharve06/encoded_OASIS-3_CT' --n=60 --random_state=3001"
# ...

# %%
experiments_path = '/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/new/WMD'
labels_path = '/cluster/tufts/hugheslabkp/data_irb_required/LinearProbing/sbi_labels'
random_states = [1001, 2001, 3001, 4001, 5001, 6001, 7001, 8001, 9001, 10001, 11001, 12001, 13001, 14001, 15001]
ns = [60, 94, 147, 230, 360, 414, 475]
count = 0
for n, random_state in itertools.product(ns, random_states):
    if not os.path.isfile('{}/n={}_random_state={}.csv'.format(experiments_path, n, random_state)):    
        count += 1
        print('    "python ../src/finetune_3D.py --experiments_path=\'{}\' --labels_path=\'{}\' --n={} --random_state={}"'.format(experiments_path, labels_path, n, random_state))
print(count)
# Out:
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/new/WMD' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/LinearProbing/sbi_labels' --n=60 --random_state=1001"
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/new/WMD' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/LinearProbing/sbi_labels' --n=60 --random_state=2001"
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/new/WMD' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/LinearProbing/sbi_labels' --n=60 --random_state=3001"
# ...

# %%
experiments_path = '/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/varying_max_slices/WMD/max_slices='
labels_path = '/cluster/tufts/hugheslabkp/data_irb_required/wmd_labels'
random_states = [6001, 7001, 8001, 9001, 10001]
ns = [500]
slices = [5, 6, 7, 8, 9, 10, 20, 30, 40, 50, 100, 200, 300]
count = 0
for n, random_states, max_slices in itertools.product(ns, random_states, slices):
    count += 1
    print('    "python ../src/finetune_3D.py --experiments_path=\'{}{}\' --labels_path=\'{}\' --max_slices={} --n={} --random_state={}"'.format(experiments_path, max_slices, labels_path, max_slices, n, random_states))
print(count)
# Out:
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/varying_max_slices/WMD/max_slices=5' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/wmd_labels' --max_slices=5 --n=500 --random_state=6001"
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/varying_max_slices/WMD/max_slices=6' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/wmd_labels' --max_slices=6 --n=500 --random_state=6001"
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/varying_max_slices/WMD/max_slices=7' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/wmd_labels' --max_slices=7 --n=500 --random_state=6001"
# ...

# %%
experiments_path = '/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/Head2Toe/WMD_mean_loss_L1'
labels_path = '/cluster/tufts/hugheslabkp/data_irb_required/Head2Toe/wmd_labels'
random_states = [1001, 2001, 3001, 4001, 5001]
ns = [500]
count = 0
for n, random_states in itertools.product(ns, random_states):
    count += 1
    print('    "python ../src/finetune_3D.py --experiments_path=\'{}\' --labels_path=\'{}\' --lrs=0.1 --n={} --random_state={}"'.format(experiments_path, labels_path, n, random_states))
print(count)
# Out:
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/Head2Toe/WMD_mean_loss_L1' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/Head2Toe/wmd_labels' --lrs=0.1 --n=500 --random_state=1001"
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/Head2Toe/WMD_mean_loss_L1' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/Head2Toe/wmd_labels' --lrs=0.1 --n=500 --random_state=2001"
#     "python ../src/finetune_3D.py --experiments_path='/cluster/home/eharve06/extrapolating-classifier-accuracy-to-bigger-datasets/experiments/Head2Toe/WMD_mean_loss_L1' --labels_path='/cluster/tufts/hugheslabkp/data_irb_required/Head2Toe/wmd_labels' --lrs=0.1 --n=500 --random_state=3001"
# ...
